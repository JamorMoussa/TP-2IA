# %% [markdown]
# # TP2 : Manipulation des images

# %%
import cv2
import matplotlib.pyplot as plt

# %%
def plot_rbg(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

# %% [markdown]
# #### Load image :

# %%
img = cv2.imread("./src/img.jpg")

# %%
plot_rbg(img)

# %% [markdown]
# #### Load image in gray scale :

# %%
img_g = cv2.imread("./src/img.jpg", 0)

# %%
plot_rbg(img_g)

# %% [markdown]
# #### display image:

# %%
cv2.imshow("window", img)

# %% [markdown]
# ![image.png](attachment:acc858d1-d387-4460-8254-66c6e0b21376.png)

# %% [markdown]
# #### write image :

# %%
cv2.imwrite("./src/writed_img.png", img)
# Out:
# True

# %% [markdown]
# ![image.png](attachment:2758efce-85f7-4d87-a88f-2832f3b3edab.png)

# %% [markdown]
# #### shape of an image :

# %%
# (rwos, columns, number channels)
img.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# #### size of an image :

# %%
img.size
# Out:
# 120000

# %% [markdown]
# #### data type of an image :

# %%
img.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# 'uint8' means it's unsigned integer, coded in 8 bits (0, 255)

# %%
img_g = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img_g, cmap="gray")

# %%
img_hsv = cv2.cvtColor(img, cv2. COLOR_BGR2HSV)

# %%
plt.imshow(img_hsv)
