# %% [markdown]
# # Segmentation d’une image

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
def cv2_imshow(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

# %%
def ax_plot(img, ax):
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_RGB2BGR))

# %%
img = cv2.imread("../img.jpg", 0)

# %%
cv2_imshow(img)

# %% [markdown]
# ## 1. Seuillage simple :

# %%
types = [cv2.THRESH_BINARY, cv2.THRESH_BINARY_INV, cv2.THRESH_TRUNC, cv2.THRESH_TOZERO, cv2.THRESH_TOZERO_INV]

# %%
def threshold_type(img):
    for i in range(5):
        ax = plt.subplot(3, 2, i+1)
        img_ = cv2.threshold(img, 135, 255, types[i])[1]
        ax_plot(img_, ax)
threshold_type(img)

# %%
cv2_imshow(cv2.threshold(img, 135, 255, cv2.THRESH_BINARY)[1])

# %% [markdown]
# ## 2. Seuillage adaptatif

# %%
adpt_method = [cv2.ADAPTIVE_THRESH_MEAN_C, cv2.ADAPTIVE_THRESH_GAUSSIAN_C]

# %%
def adpt_threshold(img, adpt_m):
    for i in range(5):
        ax = plt.subplot(3, 2, i+1)
        try:
            img_ = cv2.adaptiveThreshold( img, 255, adpt_m, types[i], 11, 2)
        except:
            pass
        ax_plot(img_, ax)

# %%
for i in (0,1):
    adpt_threshold(img, adpt_method[i])

# %% [markdown]
# ##### Comparaison :
# On observe que le seuillage adaptatif donne de meilleurs résultats que le seuillage simple, car il permet de mieux déterminer les contours.

# %% [markdown]
# ## 3. Méthode d’Otsu

# %%
def adpt_threshold_Otsu(img, adpt_m):
    for i in range(5):
        ax = plt.subplot(3, 2, i+1)
        try:
            img_ = cv2.threshold(img, 135, 255, types[i])[1]
            ax_plot(img_, ax)
        except:
            pass

# %%
for i in (0,1):
    adpt_threshold_Otsu(img, adpt_method[i])
